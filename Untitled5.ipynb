# %% [markdown]
# <a href="https://colab.research.google.com/github/advinsuryavanshi/bookingTickets1.0/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1349, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#                                      review_title  \
# 282  The cable works but is not 65W as advertised
# 324                               Awesome Product
#
#                                         review_content  \
# 282  I have a pd supported car charger and I bought...
# 324  Quick delivery.Awesome ProductPacking was good...
#
#                                               img_link  \
# 282  https://m.media-amazon.com/images/W/WEBP_40237...
# 324  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
#                                           product_link
# 282  https://www.amazon.in/Amazon-Brand-Charging-Su...
# 324  https://www.amazon.in/REDTECH-Lightning-Certif...

# %%
df.dropna(how='any', inplace=True)

# %%
df.shape
# Out:
# (1463, 16)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df['category']= df.category.apply(lambda x: x.split('|')[0])
df['discounted_price'] = df.discounted_price.apply(lambda x: x.replace('₹','').replace(',','')).astype(float)
df['actual_price'] = df.actual_price.apply(lambda x: x.replace('₹','').replace(',','')).astype(float)
df['rating_count'] = df.rating_count.astype(str).apply(lambda x: x.replace(',','')).astype(int)
df['discount_percentage'] = df.discount_percentage.apply(lambda x: x.replace('%','')).astype(float)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                 category  discounted_price  actual_price  discount_percentage  \
# 0  Computers&Accessories             399.0        1099.0                 64.0
# 1  Computers&Accessories             199.0         349.0                 43.0
# 2  Computers&Accessories             199.0        1899.0                 90.0
# 3  Computers&Accessories             329.0         699.0                 53.0
# 4  Computers&Accessories             154.0         399.0                 61.0
#
#   rating  rating_count                                      about_product  \
# 0    4.2         24269  High Compatibility : Compatible With iPhone 12...
# 1    4.0         43994  Compatible with all Type C enabled devices, be...
# 2    3.9          7928  【 Fast Charger& Data Sync】-With built-in safet...
# 3    4.2         94363  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4    4.2         16905  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df['category'].unique()
# Out:
# array(['Computers&Accessories', 'Electronics', 'MusicalInstruments',
#        'OfficeProducts', 'Home&Kitchen', 'HomeImprovement', 'Toys&Games',
#        'Car&Motorbike', 'Health&PersonalCare'], dtype=object)

# %%
df.sort_values(by='rating_count', ascending=False, inplace=True)

# %%
df.head()
# Out:
#      product_id                                       product_name  \
# 12   B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 65   B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 47   B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 684  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 400  B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...
#
#         category  discounted_price  actual_price  discount_percentage rating  \
# 12   Electronics             219.0         700.0                 69.0    4.4
# 65   Electronics             309.0        1400.0                 78.0    4.4
# 47   Electronics             309.0         475.0                 35.0    4.4
# 684  Electronics             219.0         700.0                 69.0    4.4
# 400  Electronics             379.0         999.0                 62.0    4.1
#
#      rating_count                                      about_product  \
# 12         426973  Flexible, lightweight HDMI cable for connectin...
# 65         426973  HDMI A Male to A Male Cable: Supports Ethernet...
# 47         426973  Please select appropriate display resolution &...
# 684        426972  Flexible, lightweight HDMI cable for connectin...
# 400        363713  The perfect way to add some style and stand ou...
#
#                                                user_id  \
# 12   AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 65   AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 47   AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 684  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 400  AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
#
#                                              user_name  \
# 12   Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 65   Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 47   Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 684  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 400  tarun kumar,mahesh radheshyam tawari,Blackspad...
#
#                                              review_id  \
# 12   R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 65   R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 47   R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 684  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 400  R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
#
#                                           review_title  \
# 12   It's quite good and value for money,Works well...
# 65   It's quite good and value for money,Works well...
# 47   It's quite good and value for money,Works well...
# 684  It's quite good and value for money,Works well...
# 400  Best value for money,HEAD PHONE POUCH NOT RECE...
#
#                                         review_content  \
# 12   I am using it for 14 days now. The experience ...
# 65   I am using it for 14 days now. The experience ...
# 47   I am using it for 14 days now. The experience ...
# 684  I am using it for 14 days now. The experience ...
# 400  The sound quality of this earphone are really ...
#
#                                               img_link  \
# 12   https://m.media-amazon.com/images/I/41nPYaWA+M...
# 65   https://m.media-amazon.com/images/I/41eJqkFjCR...
# 47   https://m.media-amazon.com/images/I/41bCxnHksn...
# 684  https://m.media-amazon.com/images/I/41nPYaWA+M...
# 400  https://m.media-amazon.com/images/I/31qVddHyy5...
#
#                                           product_link
# 12   https://www.amazon.in/AmazonBasics-Flexible-HD...
# 65   https://www.amazon.in/AmazonBasics-High-Speed-...
# 47   https://www.amazon.in/AmazonBasics-High-Speed-...
# 684  https://www.amazon.in/AmazonBasics-Flexible-HD...
# 400  https://www.amazon.in/Boat-BassHeads-100-Inspi...

# %%
df.drop_duplicates(subset='product_id', keep='first', inplace=True, ignore_index=True)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 1     B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 2     B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 3     B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...
# 4     B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...
# ...          ...                                                ...
# 1344  B0BNLFQDG2  Longway Blaze 2 Rod Quartz Room Heater (White,...
# 1345  B0BL3R4RGS  VAPJA® Portable Mini Juicer Cup Blender USB Re...
# 1346  B0BGPN4GGH  Lifelong LLQH925 Dyno Quartz Heater 2 Power se...
# 1347  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1348  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
#
#           category  discounted_price  actual_price  discount_percentage  \
# 0      Electronics             219.0         700.0                 69.0
# 1      Electronics             309.0        1400.0                 78.0
# 2      Electronics             309.0         475.0                 35.0
# 3      Electronics             379.0         999.0                 62.0
# 4      Electronics             349.0         999.0                 65.0
# ...            ...               ...           ...                  ...
# 1344  Home&Kitchen             929.0        2199.0                 58.0
# 1345  Home&Kitchen             649.0         999.0                 35.0
# 1346  Home&Kitchen            1099.0        2400.0                 54.0
# 1347  Home&Kitchen            1299.0        2495.0                 48.0
# 1348  Home&Kitchen             199.0         999.0                 80.0
#
#      rating  rating_count                                      about_product  \
# 0       4.4        426973  Flexible, lightweight HDMI cable for connectin...
# 1       4.4        426973  HDMI A Male to A Male Cable: Supports Ethernet...
# 2       4.4        426973  Please select appropriate display resolution &...
# 3       4.1        363713  The perfect way to add some style and stand ou...
# 4       4.1        363713  The perfect way to add some style and stand ou...
# ...     ...           ...                                                ...
# 1344    3.7             4                              Power Consumed: 800 W
# 1345    3.6             4  【USB Rechargeable & Great Portability】 The per...
# 1346    3.8             4  Meant for Spot Heating; Voltage/Frequency: 230...
# 1347      2             2  Khaitan Orfin Fan heater for Home and kitchen|...
# 1348    3.1             2  Versatile, Protects Your Clothes: MoveCatcher ...
#
#                                                 user_id  \
# 0     AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 1     AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 2     AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 3     AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
# 4     AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
# ...                                                 ...
# 1344  AFVRAZD6HB5ALMMLJRZYAA45RKFQ,AGUO5ELH4U5ORQ4F4...
# 1345  AH7CVQ6755UNVDKSBS2CKWMHOCZQ,AFMAYVBVIPFZYBTDG...
# 1346  AEB475WQGOIS7R5P667OS3Y4YYSQ,AH7D2QWLLWMHIP2H3...
# 1347  AGHT3K4KSG5MAQUSXRDT5VNB73GA,AE4Q5XQ7SZW35EEUJ...
# 1348                       AFPKVN5KLHB4MHSYDS25Q5MIWWKQ
#
#                                               user_name  \
# 0     Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 1     Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 2     Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 3     tarun kumar,mahesh radheshyam tawari,Blackspad...
# 4     tarun kumar,mahesh radheshyam tawari,Blackspad...
# ...                                                 ...
# 1344                   Amit,Chahat Goyal,Gurpiyar Singh
# 1345                                     Dinesh,Anshika
# 1346                             Avi kaur,Bhatia,ayonao
# 1347                          Manidipa Sengupta,Vidisha
# 1348                                          Kunal Sen
#
#                                               review_id  \
# 0     R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 1     R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 2     R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 3     R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
# 4     R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
# ...                                                 ...
# 1344        R34GHCVBN6M7BX,R3OA62LXAITW86,R3YGN1PYLTA95
# 1345                      R27XB7WNFY9NJ3,R24HCMD10NT57S
# 1346        R32KN5G7FW7ZJ9,RGFPF1FPU9POV,R166LGSC344H4W
# 1347                       R1OO2ED6615EX1,RR4S5JTJMCPA5
# 1348                                     R18OKMWGX8SA0L
#
#                                            review_title  \
# 0     It's quite good and value for money,Works well...
# 1     It's quite good and value for money,Works well...
# 2     It's quite good and value for money,Works well...
# 3     Best value for money,HEAD PHONE POUCH NOT RECE...
# 4     Best value for money,HEAD PHONE POUCH NOT RECE...
# ...                                                 ...
# 1344       Ok product,Worth buying product,Must buyyyyy
# 1345  As smooth as it can and as fast as possible,Wr...
# 1346  Compact and effective,Very handy and useful pr...
# 1347                      Bad quality,Amazing product..
# 1348                                            Useless
#
#                                          review_content  \
# 0     I am using it for 14 days now. The experience ...
# 1     I am using it for 14 days now. The experience ...
# 2     I am using it for 14 days now. The experience ...
# 3     The sound quality of this earphone are really ...
# 4     The sound quality of this earphone are really ...
# ...                                                 ...
# 1344  2 rods can not be switched seperately, selecti...
# 1345  Tried for two days good experience and great p...
# 1346  Pretty lightweight and solves the purpose.,I l...
# 1347  The heating capacity is zero .Moreover i have ...
# 1348  Does not work as advertised at all. The pieces...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/I/41nPYaWA+M...
# 1     https://m.media-amazon.com/images/I/41eJqkFjCR...
# 2     https://m.media-amazon.com/images/I/41bCxnHksn...
# 3     https://m.media-amazon.com/images/I/31qVddHyy5...
# 4     https://m.media-amazon.com/images/I/31J6I7SrLX...
# ...                                                 ...
# 1344  https://m.media-amazon.com/images/W/WEBP_40237...
# 1345  https://m.media-amazon.com/images/W/WEBP_40237...
# 1346  https://m.media-amazon.com/images/W/WEBP_40237...
# 1347  https://m.media-amazon.com/images/W/WEBP_40237...
# 1348  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/AmazonBasics-Flexible-HD...
# 1     https://www.amazon.in/AmazonBasics-High-Speed-...
# 2     https://www.amazon.in/AmazonBasics-High-Speed-...
# 3     https://www.amazon.in/Boat-BassHeads-100-Inspi...
# 4     https://www.amazon.in/Boat-BassHeads-100-Inspi...
# ...                                                 ...
# 1344  https://www.amazon.in/Longway-Blaze-Quartz-Hea...
# 1345  https://www.amazon.in/Portable-Rechargeable-Sm...
# 1346  https://www.amazon.in/Lifelong-LLQH925-setting...
# 1347  https://www.amazon.in/Khaitan-ORFin-heater-Hom...
# 1348  https://www.amazon.in/Hair-Removers-Laundry-Re...
#
# [1349 rows x 16 columns]

# %%
final_df = df[['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 
               'discount_percentage', 'rating', 'rating_count', 'user_id', 'review_id']]

# %%
final_df.head()
# Out:
#    product_id                                       product_name     category  \
# 0  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...  Electronics
# 1  B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...  Electronics
# 2  B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...  Electronics
# 3  B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...  Electronics
# 4  B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...  Electronics
#
#    discounted_price  actual_price  discount_percentage rating  rating_count  \
# 0             219.0         700.0                 69.0    4.4        426973
# 1             309.0        1400.0                 78.0    4.4        426973
# 2             309.0         475.0                 35.0    4.4        426973
# 3             379.0         999.0                 62.0    4.1        363713
# 4             349.0         999.0                 65.0    4.1        363713
#
#                                              user_id  \
# 0  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 1  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 2  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 3  AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
# 4  AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
#
#                                            review_id
# 0  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 1  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 2  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 3  R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
# 4  R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...

# %%
df.head()
# Out:
#    product_id                                       product_name     category  \
# 0  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...  Electronics
# 1  B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...  Electronics
# 2  B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...  Electronics
# 3  B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...  Electronics
# 4  B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...  Electronics
#
#    discounted_price  actual_price  discount_percentage rating  rating_count  \
# 0             219.0         700.0                 69.0    4.4        426973
# 1             309.0        1400.0                 78.0    4.4        426973
# 2             309.0         475.0                 35.0    4.4        426973
# 3             379.0         999.0                 62.0    4.1        363713
# 4             349.0         999.0                 65.0    4.1        363713
#
#                                        about_product  \
# 0  Flexible, lightweight HDMI cable for connectin...
# 1  HDMI A Male to A Male Cable: Supports Ethernet...
# 2  Please select appropriate display resolution &...
# 3  The perfect way to add some style and stand ou...
# 4  The perfect way to add some style and stand ou...
#
#                                              user_id  \
# 0  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 1  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 2  AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ,AFY5TVFOMVHGBPBTI...
# 3  AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
# 4  AF4MVO4JNFDEPWFKZO62OAJKRIWA,AHVPAXEWPATRASBKH...
#
#                                            user_name  \
# 0  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 1  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 2  Rishav Gossain,Shashank Mallamraju,Purnendu,gu...
# 3  tarun kumar,mahesh radheshyam tawari,Blackspad...
# 4  tarun kumar,mahesh radheshyam tawari,Blackspad...
#
#                                            review_id  \
# 0  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 1  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 2  R1FKOKZ3HHKJBZ,R2WNMZI1EXTA0H,RCA1M3W4RIXUR,R3...
# 3  R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
# 4  R2DD2M5YARW7R2,R2M9ZYNGGV1ZLN,RNWNTRNLSJWSB,R3...
#
#                                         review_title  \
# 0  It's quite good and value for money,Works well...
# 1  It's quite good and value for money,Works well...
# 2  It's quite good and value for money,Works well...
# 3  Best value for money,HEAD PHONE POUCH NOT RECE...
# 4  Best value for money,HEAD PHONE POUCH NOT RECE...
#
#                                       review_content  \
# 0  I am using it for 14 days now. The experience ...
# 1  I am using it for 14 days now. The experience ...
# 2  I am using it for 14 days now. The experience ...
# 3  The sound quality of this earphone are really ...
# 4  The sound quality of this earphone are really ...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/I/41nPYaWA+M...
# 1  https://m.media-amazon.com/images/I/41eJqkFjCR...
# 2  https://m.media-amazon.com/images/I/41bCxnHksn...
# 3  https://m.media-amazon.com/images/I/31qVddHyy5...
# 4  https://m.media-amazon.com/images/I/31J6I7SrLX...
#
#                                         product_link
# 0  https://www.amazon.in/AmazonBasics-Flexible-HD...
# 1  https://www.amazon.in/AmazonBasics-High-Speed-...
# 2  https://www.amazon.in/AmazonBasics-High-Speed-...
# 3  https://www.amazon.in/Boat-BassHeads-100-Inspi...
# 4  https://www.amazon.in/Boat-BassHeads-100-Inspi...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,5))
sns.histplot(data=final_df, x='category', stat='percent')

# %%
sns.regplot(data=final_df, x='discounted_price', y='rating_count', )
